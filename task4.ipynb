# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-fa975d84-f238-4ebe-bca8-1a8559297034" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-fa975d84-f238-4ebe-bca8-1a8559297034">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv("cancer.csv")

# %%
df.head()
# Out:
#          Id Diagnosis  Radius (mean)  Texture (mean)  Perimeter (mean)  \
# 0   8510426         B         13.540           14.36             87.46
# 1   8510653         B         13.080           15.71             85.63
# 2   8510824         B          9.504           12.44             60.34
# 3    854941         B         13.030           18.42             82.61
# 4  85713702         B          8.196           16.84             51.71
#
#    Area (mean)  Smoothness (mean)  Compactness (mean)  Concavity (mean)  \
# 0        566.3            0.09779             0.08129           0.06664
# 1        520.0            0.10750             0.12700           0.04568
# 2        273.9            0.10240             0.06492           0.02956
# 3        523.8            0.08983             0.03766           0.02562
# 4        201.9            0.08600             0.05943           0.01588
#
#    Concave points (mean)  ...  Radius (worst)  Texture (worst)  \
# ...

# %%
print(df.columns)
# Out:
# Index(['Id', 'Diagnosis', 'Radius (mean)', 'Texture (mean)',
#        'Perimeter (mean)', 'Area (mean)', 'Smoothness (mean)',
#        'Compactness (mean)', 'Concavity (mean)', 'Concave points (mean)',
#        'Symmetry (mean)', 'Fractal dimension (mean)', 'Radius (se)',
#        'Texture (se)', 'Perimeter (se)', 'Area (se)', 'Smoothness (se)',
#        'Compactness (se)', 'Concavity (se)', 'Concave points (se)',
#        'Symmetry (se)', 'Fractal dimension (se)', 'Radius (worst)',
#        'Texture (worst)', 'Perimeter (worst)', 'Area (worst)',
#        'Smoothness (worst)', 'Compactness (worst)', 'Concavity (worst)',
#        'Concave points (worst)', 'Symmetry (worst)',
#        'Fractal dimension (worst)'],
#       dtype='object')

# %%
df.columns = df.columns.str.strip()

# %%
print(df.columns.tolist())
# Out:
# ['Id', 'Diagnosis', 'Radius (mean)', 'Texture (mean)', 'Perimeter (mean)', 'Area (mean)', 'Smoothness (mean)', 'Compactness (mean)', 'Concavity (mean)', 'Concave points (mean)', 'Symmetry (mean)', 'Fractal dimension (mean)', 'Radius (se)', 'Texture (se)', 'Perimeter (se)', 'Area (se)', 'Smoothness (se)', 'Compactness (se)', 'Concavity (se)', 'Concave points (se)', 'Symmetry (se)', 'Fractal dimension (se)', 'Radius (worst)', 'Texture (worst)', 'Perimeter (worst)', 'Area (worst)', 'Smoothness (worst)', 'Compactness (worst)', 'Concavity (worst)', 'Concave points (worst)', 'Symmetry (worst)', 'Fractal dimension (worst)']

# %%
df.columns = df.columns.str.strip()

print(df.columns.tolist())
# Out:
# ['Id', 'Diagnosis', 'Radius (mean)', 'Texture (mean)', 'Perimeter (mean)', 'Area (mean)', 'Smoothness (mean)', 'Compactness (mean)', 'Concavity (mean)', 'Concave points (mean)', 'Symmetry (mean)', 'Fractal dimension (mean)', 'Radius (se)', 'Texture (se)', 'Perimeter (se)', 'Area (se)', 'Smoothness (se)', 'Compactness (se)', 'Concavity (se)', 'Concave points (se)', 'Symmetry (se)', 'Fractal dimension (se)', 'Radius (worst)', 'Texture (worst)', 'Perimeter (worst)', 'Area (worst)', 'Smoothness (worst)', 'Compactness (worst)', 'Concavity (worst)', 'Concave points (worst)', 'Symmetry (worst)', 'Fractal dimension (worst)']

# %%
chain_counts = df["Diagnosis"].value_counts()

print(chain_counts.head(10))
# Out:
# Diagnosis
# B    357
# M    212
# Name: count, dtype: int64

# %%
top_chains = chain_counts.head(10)

top_chains
# Out:
# Diagnosis
# B    357
# M    212
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10,5))

top_chains.plot(kind="bar")

plt.title("Top 10 Restaurant Chains")

plt.xlabel("Restaurant Name")

plt.ylabel("Number of Outlets")

plt.show()

# %%
chain_ratings = df.groupby("Diagnosis")["Radius (mean)"].mean()

top_chain_ratings = chain_ratings.sort_values(ascending=False).head(10)

print(top_chain_ratings)
# Out:
# Diagnosis
# M    17.462830
# B    12.146524
# Name: Radius (mean), dtype: float64

# %%
plt.figure(figsize=(10,5))

top_chain_ratings.plot(kind="bar")

plt.title("Top Rated Restaurant Chains")

plt.ylabel("Average Rating")

plt.show()

# %%
chain_votes = df.groupby("Diagnosis")["Area (mean)"].sum()

top_chain_votes = chain_votes.sort_values(ascending=False).head(10)

print(top_chain_votes)
# Out:
# Diagnosis
# M    207415.8
# B    165216.1
# Name: Area (mean), dtype: float64

# %%
plt.figure(figsize=(10,5))

top_chain_votes.plot(kind="bar")

plt.title("Most Voted Restaurant Chains")

plt.ylabel("Total Votes")

plt.show()
